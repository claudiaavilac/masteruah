# %%
import folium
import webbrowser
import pandas as pd

# %%
mercaditos=pd.read_excel('DIRECTORIO_DE_MERCADOS_DE_ABASTOS.xlsx')

# %%
mercaditos.head()
# Out:
#   DEPARTAMENTO   PROVINCIA   DISTRITO SECTOR AREA_TRABAJO   ZONA MANZANA  \
# 0        TACNA       TACNA      TACNA   ST29         AT76   0100     039
# 1        PIURA      TALARA    MANCORA   ST25         AT67  00200     025
# 2        TACNA   CANDARAVE  CANDARAVE   ST29         AT76   9999     999
# 3         PUNO    CARABAYA   OLLACHEA   ST26         AT70  99999    9999
# 4    CAJAMARCA  SAN MIGUEL     NIEPOS   ST07         AT15  99999    9999
#
#    FRENTE     GPS_LON     GPS_LAT  ...  \
# 0     1.0  -70,260222  -18,002878  ...
# 1     1.0  -81,050196   -4,107388  ...
# 2    99.0  -70,251163  -17,268788  ...
# 3    99.0  -70,471193   -13,79408  ...
# 4    99.0  -79,129246   -6,927231  ...
#
#                                         REFERENCIA  \
# 0                          AL FRENTE DE LA ROTONDA
# 1                         FRENTE A TIENDA MARCIMEX
# 2                       A MEDIA CUADRA DE LA PLAZA
# 3  A DOS CUADRA DE LA PLAZA DE ARMAS  BARRIO ABAJO
# ...

# %%
mercaditos=mercaditos[mercaditos.PROVINCIA.isin(['LIMA'])]

# %%
mercaditos.head()
# Out:
#    DEPARTAMENTO PROVINCIA       DISTRITO SECTOR AREA_TRABAJO ZONA MANZANA  \
# 7          LIMA      LIMA          LURIN   ST17         AT45  011     047
# 35         LIMA      LIMA    SANTA ANITA   ST18         AT49  013     060
# 39         LIMA      LIMA  PUENTE PIEDRA   ST19         AT53   20     14K
# 44         LIMA      LIMA           LIMA   ST16         AT42   32       7
# 46         LIMA      LIMA     PACHACAMAC   ST17         AT45   02     049
#
#     FRENTE     GPS_LON     GPS_LAT  ...  \
# 7      4.0   -76869621   -12276506  ...
# 35     1.0  -76,947609  -12,038805  ...
# 39     3.0   -77,08006  -11,848124  ...
# 44     3.0  -77,007812  -12,059042  ...
# 46     2.0  -76,863643  -12,230204  ...
#
#                                            REFERENCIA  \
# 7   URBANIZACION VICTOR RAUL HAYA DE LA TORRE LA V...
# 35                  AV. LA METROPOLITANA / LA CULTURA
# 39                                    PARADERO VIÃ‘AS
# ...
