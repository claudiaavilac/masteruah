# %%
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster

# %%
m_1 = folium.Map(location=[-12.0451206,-77.0981222], tiles='openstreetmap', zoom_start=10)
m_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import geopandas as gpd
#import geoplot.crs as gcrs
#import geoplot as gplt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

comisarias= gpd.read_file('comisarias_fuente_cenepred.shp')

# %%
comisarias.dpto.unique()
# Out:
# array(['LA LIBERTAD', 'AREQUIPA', 'HUANUCO', 'LIMA', 'CAJAMARCA',
#        'APURIMAC', 'LAMBAYEQUE', 'AMAZONAS', 'TUMBES', 'CUSCO', 'JUNIN',
#        'ANCASH', 'SAN MARTIN', 'UCAYALI', 'ICA', 'AYACUCHO', 'PASCO',
#        'LORETO', 'PIURA', 'MADRE DE DIOS', 'HUANCAVELICA', 'PUNO',
#        'TACNA', 'MOQUEGUA', 'CALLAO', 'AMAZONAS - SAN MARTIN', 'JUNÍN',
#        'AMAZONAS - CAJAMARCA'], dtype=object)

# %%
comisarias = comisarias[comisarias.dpto.isin(['LIMA','CALLAO'])]

# %%
comisarias.to_excel('comisarias_lima.xlsx')

# %%
comisarias=pd.read_excel('comisarias_lima.xlsx')

# %%
comisarias.head(5)
# Out:
#    Unnamed: 0  objectid  dpto    prov                    dist  \
# 0           3         8  LIMA    LIMA  SAN JUAN DE LURIGANCHO
# 1           7        12  LIMA    LIMA                     ATE
# 2          22        33  LIMA  HUARAL                  HUARAL
# 3          24        35  LIMA  HUAURA                 VEGUETA
# 4          26        37  LIMA    LIMA    SAN MARTIN DE PORRES
#
#                       nombre direccion      estado capacidad  \
# 0           CPNP LA HUAYRONA       NaN  HABILITADO       NaN
# 1             CPNP SALAMANCA       NaN  HABILITADO       NaN
# 2                CPNP HUARAL       NaN  HABILITADO       NaN
# 3               CPNP VEGUETA       NaN  HABILITADO       NaN
# 4  CPNP SAN MARTIN DE PORRES       NaN  HABILITADO       NaN
#
#                observacio  ...    tipo_cdi bdcenepred fecha_act descripcio  \
# 0  Zona :96, Area: Urbana  ...  Comisarias        NaN       NaN        NaN
# 1   Zona :4, Area: Urbana  ...  Comisarias        NaN       NaN        NaN
# 2   Zona :7, Area: Urbana  ...  Comisarias        NaN       NaN        NaN
# 3   Zona :2, Area: Urbana  ...  Comisarias        NaN       NaN        NaN
# 4  Zona :50, Area: Urbana  ...  Comisarias        NaN       NaN        NaN
#
#   ccpp operador         geometry1          geometry       Long        Lat
# 0  NaN      NaN -7698890833399990 -1207579833400000 -76.988908 -12.075798
# 1  NaN      NaN -7698890833399990 -1207579833400000 -76.988908 -12.075798
# 2  NaN      NaN -7720673666599990      -11494393333 -77.206737  -0.000115
# 3  NaN      NaN -7764370143500000 -1102339019099990 -77.643701 -11.023390
# 4  NaN      NaN      -77056083333 -1202585499999990  -0.000771 -12.025855
#
# [5 rows x 25 columns]

# %%
# Create a map
m_1 = folium.Map(location=[-12.0451206,-77.0981222], tiles='cartodbpositron', zoom_start=8)

# Add points to the map
for idx, row in comisarias.iterrows():
    #Marker([row['Lat'], row['Long']]).add_to(m_2)
    Marker([row['Lat'], row['Long']]).add_to(m_1)

# Display the map
m_1.save('MAPA.html')
m_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create a base map
m_4 = folium.Map(location=[-12.0451206,-77.0981222], tiles='cartodbpositron', zoom_start=13)

def color_producer(val):
    if val <= 12:
        return 'forestgreen'
    else:
        return 'darkred'

# Add a bubble map to the base map
for i in range(0,len(comisarias)):
    Circle(
        location=[comisarias.iloc[i]['Lat'], comisarias.iloc[i]['Long']],
        radius=20,
        color=color_producer(comisarias.iloc[i]['objectid'])).add_to(m_4)

# Display the map
m_4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create a base map
m_5 = folium.Map(location=[-12.0451206,-77.0981222], tiles='cartodbpositron', zoom_start=12)

# Add a heatmap to the base map
HeatMap(data=comisarias[['Lat', 'Long']], radius=10).add_to(m_5)

# Display the map
m_5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
