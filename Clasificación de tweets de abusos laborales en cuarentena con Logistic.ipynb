# %% [markdown]
# # Tipos de tweets - Pipeline

# %%
# Import libraries
import pandas as pd
import numpy as np
#import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
import nltk 
import string
import re
#%matplotlib inline
pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# ### 1. Limpiamos nuevos tweets

# %%
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD',s)
        if unicodedata.category(c)!='Mn'
    )

def normalizeString(s):
    s=unicodeToAscii(str(s).lower().strip())
    #s=re.sub(r'^https?:\/\/.*[\r\n]*',r" url ",s)
    #s=re.sub(r'''(?i)\b((?:http?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''',r" url ",s)
    #s=str(s).lower().strip()
    
    
    s=re.sub(r'www\S+',r'',s)
    s=re.sub(r'http\S+',r"",s)

    s=re.sub("(@|#)(\w+)|[_]+\w+","",s)

    #s = re.sub(r'#(a[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)','',s)
    #s=re.sub(r'[a-zA-Z]{1,2}[0-9]{1,2}[a-zA-Z]{1,2}',r'',s)
    #s=re.sub(r'[a-zA-Z]{1,2}[0-9]{1,2}',r'',s)
    
    '''
    
    '''
    
    s = re.sub(r" 0 "," cero ",s)
    s = re.sub(r" 1 "," un ",s)
    s = re.sub(r" 2 "," dos ",s)
    s = re.sub(r" 3 "," tres ",s)
    s = re.sub(r" 4 "," cuatro ",s)
    s = re.sub(r" 5 "," cinco ",s)
    s = re.sub(r" 6 "," seis ",s)
    s = re.sub(r" 7 "," siete ",s)
    s = re.sub(r" 8 "," ocho ",s)
    s = re.sub(r" 9 "," nueve ",s)
    s = re.sub(r" 10 "," diez ",s)
    s = re.sub(r" 11 "," once ",s)
    s = re.sub(r" 12 "," doce ",s)
    s = re.sub(r" 13 "," trece ",s)
    s = re.sub(r" 14 "," catorce ",s)
    s = re.sub(r" 15 "," quince ",s)
    s = re.sub(r" 16 "," dieciseis ",s)
    s = re.sub(r" 17 "," diecisiete ",s)
    s = re.sub(r" 18 "," dieciocho ",s)
    s = re.sub(r" 19 "," diecinueve ",s)
    s = re.sub(r" 20 "," veinte ",s)
    s = re.sub(r" 30 "," treinta ",s)
    s = re.sub(r" 40 "," cuarenta ",s)
    s = re.sub(r" 50 "," cincuenta ",s)
    s = re.sub(r" 60 "," sesenta ",s)
    s = re.sub(r" 70 "," setenta ",s)
    s = re.sub(r" 80 "," ochenta ",s)
    s = re.sub(r" 90 "," noventa ",s)
    
    s = re.sub(r" 100 "," cien ",s)
    s = re.sub(r" 200 "," doscientos ",s)
    s = re.sub(r" 300 "," trescientos ",s)
    s = re.sub(r" 400 "," cuatrocientos ",s)
    s = re.sub(r" 500 "," quinientos ",s)
    s = re.sub(r" 600 "," seiscientos ",s)
    s = re.sub(r" 700 "," setecientos ",s)
    s = re.sub(r" 800 "," ochocientos ",s)
    s = re.sub(r" 900 "," novencientos ",s)
    
    s = re.sub(r" 104 "," ciento cuatro ",s)
    s = re.sub(r" 1000 "," mil ",s)
    s = re.sub(r" 2018 "," dos mil dieciocho ",s)
    s = re.sub(r" 2019 "," dos mil diecinueve ",s)
    s = re.sub(r" 2020 "," dos mil veinte ",s)
    s = re.sub(r" 2030 "," dos mil treinta ",s)
    
    
    s = re.sub(r"0 ","cero ",s)
    s = re.sub(r"1 ","uno ",s)
    s = re.sub(r"2 ","dos ",s)
    s = re.sub(r"3 ","tres ",s)
    s = re.sub(r"4 ","cuatro ",s)
    s = re.sub(r"5 ","cinco ",s)
    s = re.sub(r"6 ","seis ",s)
    s = re.sub(r"7 ","siete ",s)
    s = re.sub(r"8 ","ocho ",s)
    s = re.sub(r"9 ","nueve ",s)
    s = re.sub(r"10 ","nueve ",s)
    s = re.sub(r"20 ","veinte ",s)
    s = re.sub(r"30 ","treinta ",s)
    s = re.sub(r"40 ","cuarenta ",s)
    s = re.sub(r"50 ","cincuenta ",s)
    s = re.sub(r"60 ","sesenta ",s)
    s = re.sub(r"70 ","setenta ",s)
    s = re.sub(r"80 ","ochenta ",s)
    s = re.sub(r"90 ","noventa ",s)
    s = re.sub(r"100 ","cien ",s)
    s = re.sub(r"200 ","doscientos ",s)
    s = re.sub(r"300 ","trescientos ",s)
    s = re.sub(r"400 ","cuatrocientos ",s)
    s = re.sub(r"500 ","quinientos ",s)
    s = re.sub(r"600 ","seiscientos ",s)
    s = re.sub(r"700 ","setecientos ",s)
    s = re.sub(r"800 ","ochocientos ",s)
    s = re.sub(r"900 ","novencientos ",s)
    s = re.sub(r"104 ","ciento cuatro ",s)
    s = re.sub(r"1000 ","mil ",s)
    s = re.sub(r"2018 ","dos mil dieciocho ",s)
    s = re.sub(r"2019 ","dos mil diecinueve ",s)
    s = re.sub(r"2020 ","dos mil veinte ",s)
    s = re.sub(r"2030 ","dos mil treinta ",s)
    

    
    s = re.sub(r" 0$"," cero",s)
    s = re.sub(r" 1$"," uno",s)
    s = re.sub(r" 2$"," dos",s)
    s = re.sub(r" 3$"," tres",s)
    s = re.sub(r" 4$"," cuatro",s)
    s = re.sub(r" 5$"," cinco",s)
    s = re.sub(r" 6$"," seis",s)
    s = re.sub(r" 7$"," siete",s)
    s = re.sub(r" 8$"," ocho",s)
    s = re.sub(r" 9$"," nueve",s)
    s = re.sub(r" 20$"," veinte",s)
    s = re.sub(r" 30$"," treinta",s)
    s = re.sub(r" 40$"," cuarenta",s)
    s = re.sub(r" 50$"," cincuenta",s)
    s = re.sub(r" 60$"," sesenta",s)
    s = re.sub(r" 70$"," setenta",s)
    s = re.sub(r" 80$"," ochenta",s)
    s = re.sub(r" 90$"," noventa",s)
    s = re.sub(r" 100$"," cien",s)
    s = re.sub(r" 200$"," doscientos",s)
    s = re.sub(r" 300$"," trescientos",s)
    s = re.sub(r" 400$"," cuatrocientos",s)
    s = re.sub(r" 500$"," quinientos",s)
    s = re.sub(r" 600$"," seiscientos",s)
    s = re.sub(r" 700$"," setecientos",s)
    s = re.sub(r" 800$"," ochocientos",s)
    s = re.sub(r" 900$"," novencientos",s)
    s = re.sub(r" 104$"," ciento cuatro",s)
    s = re.sub(r" 1000$"," mil",s)
    s = re.sub(r" 2018$"," dos mil dieciocho",s)
    s = re.sub(r" 2019$"," dos mil diecinueve",s)
    s = re.sub(r" 2020$"," dos mil veinte",s)
    s = re.sub(r" 2030$"," dos mil treinta",s)
    
    s = re.sub('[0-9]+','',s)
    
    #s = re.sub(r'(#[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)','',s)
    
    s=re.sub(r'<.*?>','',s)
    #s=re.sub(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''',r" url ",s)
    s=re.sub(r'(.)\1+', r'\1\1', s)
    s=re.sub(r"([.!?])", r" \1 ",s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s) ##----sin tildes
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# %% [markdown]
# ### 2.A. Vectorizamos con TFIDfVectorizer para training set

# %%
import pandas as pd
#traigo el dataset clasificado con 0 y 1
train=pd.read_excel('train.xlsx')
train=train.drop('Unnamed: 0',axis=1).fillna('')

# %%
# import and instantiate TfidfVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
vect = TfidfVectorizer(max_features=5000)
X=train.tweet

# learn the vocabulary in the training data, then use it to create a document-term matrix
X_dtm = vect.fit_transform(X)

# Guardamos modelo
#tfidf = vect.fit_transform(X)

tfidf = vect.fit(X)

#pickl
import pickle 
file_pi = open('tfidf.pkl', 'wb') 
pickle.dump(tfidf, file_pi)

# %% [markdown]
# ### 2. B. Vectorizamos con TFID para nuevos tweets

# %%
text = ["La empresa tenía que haberte pagado la deuda y despido"]

# %%
import pandas as pd
cols = ['tweet','despido', 'planilla', 'obligan', 'vacaciones',
       'virtual', 'visita', 'pago', 'guantes', 'intereses', 'cuotas', 'deuda',
       'bono', 'credito', 'encuesta', 'internet', 'recibo', 'servicios',
       'cable', 'plan', 'linea', 'seguridad', 'medida', 'precio', 'cerveza',
       'millones', 'refineria', 'gracias']

def Dataframe(text):
    test_text_frame=pd.DataFrame(text).rename(columns={0:'tweet'})
    submission_text_frame = pd.DataFrame(text_frame, columns=cols).fillna('')

# %%
# solo la columna de tweet
test_text_frame=pd.DataFrame(text).rename(columns={0:'tweet'})
test_X=test_text_frame.tweet

# %%
# con todas las columnas que va a completar
test_text_frame = pd.DataFrame(test_text_frame, columns=cols).fillna('')
test_text_frame
# Out:
#                                                tweet despido planilla obligan  \
# 0  La empresa tenía que haberte pagado la deuda y...
#
#   vacaciones virtual visita pago guantes intereses  ... cable plan linea  \
# 0                                                   ...
#
#   seguridad medida precio cerveza millones refineria gracias
# 0
#
# [1 rows x 28 columns]

# %%
# Testing phase
tf1 = pickle.load(open("tfidf.pkl", 'rb'))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# transform the test data using the earlier fitted vocabulary, into a document-term matrix
test_X_dtm = tf1.transform(test_X)
# examine the document-term matrix from X_test
print(test_X_dtm)
# Out:
#   (0, 3898)	0.1446539666093601
#   (0, 3313)	0.5495691963966258
#   (0, 2569)	0.2868388468691156
#   (0, 1530)	0.33488307381394444
#   (0, 1294)	0.47170997812647764
#   (0, 1284)	0.5100151249245296

# %% [markdown]
# ## 3. Modelo en conjunto, sin loop por modelo

# %%
# import and instantiate the Logistic Regression model
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
logreg = LogisticRegression(C=12.0)

# create submission file

cols_target = ['despido', 'planilla', 'obligan', 'vacaciones',
       'virtual', 'visita', 'pago', 'guantes', 'intereses', 'cuotas', 'deuda',
       'bono', 'credito', 'encuesta', 'internet', 'recibo', 'servicios',
       'cable', 'plan', 'linea', 'seguridad', 'medida', 'precio', 'cerveza',
       'millones', 'refineria', 'gracias']


for label in cols_target:
    print('... Processing {}'.format(label))
    y = train[label]
    # train the model using X_dtm & y
    logreg.fit(X_dtm, y)
    # compute the training accuracy
    y_pred_X = logreg.predict(X_dtm)
    print('Training accuracy is {}'.format(accuracy_score(y, y_pred_X)))
    # compute the predicted probabilities for X_test_dtm
    test_y_prob = logreg.predict_proba(test_X_dtm)[:,1]
    test_text_frame[label] = test_y_prob
# Out:
# ... Processing despido
# Training accuracy is 0.9988005997001499
# ... Processing planilla
# Training accuracy is 0.9998500749625188
# ... Processing obligan
# Training accuracy is 0.9986506746626687
# ... Processing vacaciones
# Training accuracy is 1.0
# ... Processing virtual
# Training accuracy is 0.9998500749625188
# ... Processing visita
# Training accuracy is 0.9991004497751125
# ... Processing pago
# Training accuracy is 0.9995502248875562
# ... Processing guantes
# Training accuracy is 0.9992503748125937
# ... Processing intereses
# Training accuracy is 0.999400299850075
# ... Processing cuotas
# Training accuracy is 0.9998500749625188
# ... Processing deuda
# Training accuracy is 0.9995502248875562
# ... Processing bono
# Training accuracy is 0.9998500749625188
# ... Processing credito
# Training accuracy is 1.0
# ... Processing encuesta
# Training accuracy is 1.0
# ... Processing internet
# Training accuracy is 0.9997001499250375
# ... Processing recibo
# ...

# %%
test_text_frame
# Out:
#                                                tweet   despido  planilla  \
# 0  La empresa tenía que haberte pagado la deuda y...  0.834101  0.000784
#
#     obligan  vacaciones   virtual    visita      pago   guantes  intereses  \
# 0  0.011359    0.000713  0.000452  0.001293  0.004529  0.004878   0.020187
#
#    ...     cable      plan     linea  seguridad    medida    precio   cerveza  \
# 0  ...  0.000551  0.005978  0.001657   0.000676  0.003016  0.000891  0.000969
#
#    millones  refineria   gracias
# 0  0.004596   0.001768  0.002047
#
# [1 rows x 28 columns]
